# %% [markdown]
# <a href="https://colab.research.google.com/github/pavankumarag/modern_AI/blob/main/Home_Prices_Classwork.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
#From the left menu upload this data: https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques/data?select=train.csv
df = pd.read_csv("train.csv")
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.columns.to_list()
# Out:
# ['Id',
#  'MSSubClass',
#  'MSZoning',
#  'LotFrontage',
#  'LotArea',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'MasVnrArea',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinSF1',
#  'BsmtFinType2',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'KitchenQual',
#  'TotRmsAbvGrd',
#  'Functional',
#  'Fireplaces',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
# ...

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
plt.scatter(df['LotArea'],df['SalePrice'])

# %%
from sklearn.preprocessing import LabelEncoder

for col in df.columns:
  if pd.api.types.is_numeric_dtype(df[col].dtype):
    if df[col].isnull().any():
      df[col].fillna(df[col].median(),inplace=True)
  else:
    df[col] = LabelEncoder().fit_transform(df[col])

# %%
df
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 0        1          60         3         65.0     8450       1      2
# 1        2          20         3         80.0     9600       1      2
# 2        3          60         3         68.0    11250       1      2
# 3        4          70         3         60.0     9550       1      2
# 4        5          60         3         84.0    14260       1      2
# ...    ...         ...       ...          ...      ...     ...    ...
# 1455  1456          60         3         62.0     7917       1      2
# 1456  1457          20         3         85.0    13175       1      2
# 1457  1458          70         3         66.0     9042       1      2
# 1458  1459          20         3         68.0     9717       1      2
# 1459  1460          20         3         75.0     9937       1      2
#
#       LotShape  LandContour  Utilities  ...  PoolArea  PoolQC  Fence  \
# ...

# %%
y = df["SalePrice"]
X = df.drop("SalePrice",axis="columns")

# %%
X
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 0        1          60         3         65.0     8450       1      2
# 1        2          20         3         80.0     9600       1      2
# 2        3          60         3         68.0    11250       1      2
# 3        4          70         3         60.0     9550       1      2
# 4        5          60         3         84.0    14260       1      2
# ...    ...         ...       ...          ...      ...     ...    ...
# 1455  1456          60         3         62.0     7917       1      2
# 1456  1457          20         3         85.0    13175       1      2
# 1457  1458          70         3         66.0     9042       1      2
# 1458  1459          20         3         68.0     9717       1      2
# 1459  1460          20         3         75.0     9937       1      2
#
#       LotShape  LandContour  Utilities  ...  ScreenPorch  PoolArea  PoolQC  \
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=3)

# %%
X_train
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 727    728          20         3         64.0     7314       1      2
# 328    329          75         3         69.0    11888       1      1
# 958    959          20         3         65.0     8450       1      2
# 126    127         120         3         69.0     4928       1      2
# 1102  1103          20         3         70.0     7000       1      2
# ...    ...         ...       ...          ...      ...     ...    ...
# 789    790          60         3         69.0    12205       1      2
# 256    257          60         1         64.0     8791       1      2
# 968    969          50         4         50.0     5925       1      2
# 952    953          85         3         60.0     7200       1      2
# 1273  1274          80         3        124.0    11512       1      2
#
#       LotShape  LandContour  Utilities  ...  ScreenPorch  PoolArea  PoolQC  \
# ...

# %%
from sklearn.linear_model import LinearRegression
trainer = LinearRegression()
trainer.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
trainer.score(X_test,y_test)
# Out:
# 0.49313944592995296

# %%
X_test.iloc[1]
# Out:
# Id                951.0
# MSSubClass         20.0
# MSZoning            3.0
# LotFrontage        60.0
# LotArea          7200.0
#                   ...
# MiscVal             0.0
# MoSold              7.0
# YrSold           2007.0
# SaleType            8.0
# SaleCondition       4.0
# Name: 950, Length: 80, dtype: float64

# %%
trainer.predict(X_test.iloc[[1]])
# Out:
# array([134566.2034431])

# %%
import seaborn as sns
sns.set()

top_features = df.corr()[['SalePrice']].sort_values(by=['SalePrice'],ascending=False).head(30)
plt.figure(figsize=(5,10))
sns.heatmap(top_features,cmap='rainbow', annot=True,annot_kws={"size": 16}, vmin=-1)
# Out:
# <Axes: >
